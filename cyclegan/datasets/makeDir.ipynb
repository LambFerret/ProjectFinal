# %%
import os 
path_list = ['./spring2summer/testA', './spring2summer/testB', './spring2summer/trainA','./spring2summer/trainB',]

for path in path_list:
    os.makedirs(path, exist_ok=True)

# %%
# testA/B 사진 복사
import os
import shutil

origin = 'C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/'
copy = 'C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA'

# oPath 경로의 파일 읽기
file_list = os.listdir(origin)

# 복사할 파일들을 닮을 배열 객체
copy_files = []

# Files List Create - TEXT 파일을 제외한 파일들이 이동대상 파일
for file in file_list:
	print("File : " + file)
	copy_files.append(file)

# Move Files
for cofi in copy_files:
	print('Copy File : ' + origin + ' 에 있는 ' + cofi + ' ----- > ' + copy + '로 이동하였습니다.')
	shutil.copy2(origin + '//' + cofi, copy + '\/' + cofi)
print("[info] Copy Completed.")
# Out:
# File : spring pictures10.jpg
# File : spring pictures107.jpg
# File : spring pictures117.jpg
# File : spring pictures12.jpg
# File : spring pictures17.jpg
# File : spring pictures18.jpg
# File : spring pictures2.jpg
# File : spring pictures32.jpg
# File : spring pictures5.jpg
# File : spring pictures79.jpg
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures10.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures107.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures117.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures12.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures17.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures18.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures2.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures32.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures5.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.
# Copy File : C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2fall/testA/ 에 있는 spring pictures79.jpg ----- > C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/testA로 이동하였습니다.

# %%
# crawling photos -> train 복사
import os
import shutil

origin = 'C:/Users/chohe/ProjectFinal/Google-Image-Scraper-master/photos/summer 4K Background'
copy = 'C:/Users/chohe/ProjectFinal/cyclegan/datasets/spring2summer/trainB'

# oPath 경로의 파일 읽기
file_list = os.listdir(origin)

# 복사할 파일들을 닮을 배열 객체
copy_files = []

# Files List Create - TEXT 파일을 제외한 파일들이 이동대상 파일
for file in file_list:
	print("File : " + file)
	copy_files.append(file)

# Move Files
for cofi in copy_files:
	print('Copy File : ' + origin + ' 에 있는 ' + cofi + ' ----- > ' + copy + '로 이동하였습니다.')
	shutil.copy2(origin + '\\' + cofi, copy + '\\' + cofi)
print("[info] Copy Completed.")
# Out:
# File : summer 4K Background 1.jpg
# File : summer 4K Background 100.jpg
# File : summer 4K Background 101.jpg
# File : summer 4K Background 102.jpg
# File : summer 4K Background 103.jpg
# File : summer 4K Background 104.jpg
# File : summer 4K Background 105.jpg
# File : summer 4K Background 106.jpg
# File : summer 4K Background 107.jpg
# File : summer 4K Background 108.jpg
# File : summer 4K Background 109.jpg
# File : summer 4K Background 11.jpg
# File : summer 4K Background 110.jpg
# File : summer 4K Background 12.jpg
# File : summer 4K Background 13.jpg
# File : summer 4K Background 14.jpg
# File : summer 4K Background 15.jpg
# File : summer 4K Background 16.jpg
# File : summer 4K Background 17.jpg
# File : summer 4K Background 18.jpg
# File : summer 4K Background 19.jpg
# File : summer 4K Background 2.jpg
# File : summer 4K Background 20.jpg
# File : summer 4K Background 21.jpg
# File : summer 4K Background 22.jpg
# File : summer 4K Background 23.jpg
# File : summer 4K Background 24.jpg
# File : summer 4K Background 25.jpg
# File : summer 4K Background 26.jpg
# File : summer 4K Background 27.jpg
# File : summer 4K Background 28.jpg
# File : summer 4K Background 29.jpg
# File : summer 4K Background 30.jpg
# File : summer 4K Background 31.jpg
# File : summer 4K Background 32.jpg
# File : summer 4K Background 33.jpg
# File : summer 4K Background 34.jpg
# File : summer 4K Background 35.jpg
# File : summer 4K Background 36.jpg
# File : summer 4K Background 37.jpg
