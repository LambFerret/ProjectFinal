# %% [markdown]
# <h3>Google Image Scrapper for Juypter Notebook</h3>

# %%
from GoogleImageScrapper import GoogleImageScraper
import os

webdriver_path = os.getcwd()+"\\webdriver\\chromedriver.exe"
#add new search key into array ["cat","t-shirt"]
search_keys= ['"spring" 4k', 'fall 4k']
number_of_images = 1
headless = False
#min_resolution = (width,height)
min_resolution=(0,0)
#max_resolution = (width,height)
max_resolution=(1920,1080)
for search_key in search_keys:
    image_path = os.getcwd()+"\\photos\\" + search_key.replace('"',"")
    image_scrapper = GoogleImageScraper(webdriver_path,image_path,search_key,number_of_images,headless,min_resolution,max_resolution)
    image_urls = image_scrapper.find_image_urls()
    image_scrapper.save_images(image_urls)
# Out:
# [INFO] Scraping for image link... Please wait.
# [INFO] 0. https://wallpaperaccess.com/full/1879416.jpg
# [INFO] 1. https://wallpaperaccess.com/full/1879440.jpg
# [INFO] Google search ended
# [INFO] Saving Image... Please wait...
# [ERROR] Failed to be downloaded 'str' object has no attribute 'str'
# [ERROR] Failed to be downloaded 'str' object has no attribute 'str'
# [INFO] Download Completed. Please note that some photos are not downloaded as it is not in the right format (e.g. jpg, jpeg, png)
# [INFO] Scraping for image link... Please wait.
# [INFO] 0. https://c4.wallpaperflare.com/wallpaper/307/555/701/autumn-4k-fall-foliage-wallpaper-preview.jpg
# [INFO] 1. https://images.hdqwalls.com/wallpapers/trees-fall-reflection-autumn-4k-hb.jpg
# [INFO] Google search ended
# [INFO] Saving Image... Please wait...
# [ERROR] Failed to be downloaded 'str' object has no attribute 'str'
# [ERROR] Failed to be downloaded 'str' object has no attribute 'str'
# [INFO] Download Completed. Please note that some photos are not downloaded as it is not in the right format (e.g. jpg, jpeg, png)

# %%
filename = "%s%s.%s"%(search_key + str(5),saved_extension)
filename = filename.replace("'","")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4797889a5993> in <module>
# ----> 1 filename = "%s%s.%s"%(search_key + str(5),saved_extension)
#       2 filename = filename.replace("'","")
#       3
#
# TypeError: not enough arguments for format string

# %%
saved_extension = "jpg"

# %%
search_keys= ['"spring" 4k', 'fall 4k']
for a in search_keys:
    filename = f"""{a} {str(5)}.{saved_extension}"""
    filename = filename.replace('"',"")
    print(filename)
# Out:
# spring 4k 5,jpg
# fall 4k 5,jpg
